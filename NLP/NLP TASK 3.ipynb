# %%
# Install/upgrade required libraries
# !pip install --upgrade transformers torch

# %%
from transformers import pipeline

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch

# %%
model_name = "google/flan-t5-base"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

print("✅ Model loaded successfully!")

# %%
def generate_response(user_input):

    # Strong instruction prompt
    prompt = f"""
You are a helpful AI assistant. Give a clear, correct, and detailed answer.

Question: {user_input}
Answer:
"""

    inputs = tokenizer(prompt, return_tensors="pt")

    outputs = model.generate(
        **inputs,
        max_length=150,
        do_sample=True,
        top_p=0.9,
        temperature=0.6,
        repetition_penalty=1.3
    )

    response = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return response.strip()

# %%
print("🤖 Chatbot: Hello! I am your AI assistant.")
print("Type 'exit' or 'quit' to stop.\n")

while True:

    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit"]:
        print("🤖 Chatbot: Goodbye! Have a nice day!")
        break

    reply = generate_response(user_input)
    print("🤖 Chatbot:", reply)
# Out:
# 🤖 Chatbot: Hello! I am your AI assistant.
# Type 'exit' or 'quit' to stop.
#
# You: hello
# 🤖 Chatbot: hello!.. how can i help you..
#
# You: what is Artificial Intelligence and Machine learning
# 🤖 Chatbot: Artificial Intelligence (AI) is the broad concept of machines acting, thinking, or sensing like humans, aiming to simulate intelligence. Machine Learning (ML) is a subset of AI—a technique or method that allows computers to learn from data, recognize patterns, and make decisions without being explicitly programmed for every scenario.
#
# You: how does AI work
# 🤖 Chatbot: AI works by processing vast amounts of data using algorithms to identify patterns, make predictions, and simulate human-like intelligence.
#
# You: what is python
# 🤖 Chatbot: a programming language
#
# You: exit
# 🤖 Chatbot: Goodbye! Have a nice day!
